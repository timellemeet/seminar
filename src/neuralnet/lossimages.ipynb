# %%
from results_analysis import Model

# %%
data = Model("Results/Base/Baseresults - layers [10] - training_size 60000 - epochs 20 - learning_rate 0.005 - 2019-04-05-145738.npy")
#data = Model("Results/Base/Baseresults - layers [180, 90] - training_size 60000 - epochs 20 - learning_rate 0.005 - 2019-04-06-204946.npy")

# for i in [1,2,3,4,5]:
#     print("Fold ",i)
#     data.toplosses(amount=1, fold=i)

print(data.overall_test_accuracy)
data.toplosses(amount=4)
# Out:
# 0.9297599999999999
# loss: 12.324844177466671, true: 6, predicted: 0
# loss: 13.26157852342923, true: 9, predicted: 0
# loss: 14.877302668827102, true: 9, predicted: 5
# loss: 15.859091661575468, true: 1, predicted: 5
