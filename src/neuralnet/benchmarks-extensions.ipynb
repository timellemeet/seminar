# %% [markdown]
# Importing modules

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# from sklearn.metrics import accuracy_score
from Layer import *
from network import Network
from activation_func import tanh, tanh_prime, sigmoid, sigmoid_prime, softmax, softmax_prime, relu, relu_prime
from loss_func import mse, mse_prime, cross_entropy, cross_entropy_prime
from data_func import vectorize_labels, k_fold, import_data
from performance_func import plot_error, plot_confusion_matrix
from network_queue import Queue

# %% [markdown]
# Importing data

# %%
# import data and initialize seed
np.random.seed(10)

# import data
training_size = 60000
normalize = True
training, labels, test, original_test_labels, test_labels = import_data(size=training_size, normalize=normalize)

# intializing queue
queue = Queue(training, labels, test, test_labels, original_test_labels)

#setting up the models


architectures = [
   [100,100]]
for layers in architectures:
    queue.add(
        description="batchsize, 40 epochs",
        netparams={
        "hidden_layers": layers,
        "features": 784,
        "output_classes": 10,
        "activation": relu,
        "activation_prime": relu_prime,
        "loss_activation": softmax,
        "loss_activation_prime": softmax_prime,
        "loss": cross_entropy,
        "loss_prime": cross_entropy_prime,
        "activation_alpha": 0.5
    },
    folds=5,
    params={"epochs": 40,
            "learning_rate": 5e-3,
            "batch_size": 32,
            "momentum": False,
            "weight_decay": 0})
    
#execute queue
results = queue.execute(folder="../Results/Extensions")
# Out:
# Fitting model 1/5 batchsize, 40 epochs - Fold 1 Layers: [100, 100]
# epoch 1/40   training error=0.721335  validation error=0.390270 validation accuracy=0.881250 ETA=0:14:34
# epoch 2/40   training error=0.349563  validation error=0.307406 validation accuracy=0.910250 ETA=0:13:29
# epoch 3/40   training error=0.285256  validation error=0.269617 validation accuracy=0.922333 ETA=0:12:52
# epoch 4/40   training error=0.247739  validation error=0.241727 validation accuracy=0.930083 ETA=0:12:27
# epoch 5/40   training error=0.221621  validation error=0.223290 validation accuracy=0.934167 ETA=0:12:19
# epoch 6/40   training error=0.202212  validation error=0.209654 validation accuracy=0.937333 ETA=0:12:22
# epoch 7/40   training error=0.186571  validation error=0.197560 validation accuracy=0.942167 ETA=0:11:53
# epoch 8/40   training error=0.173561  validation error=0.197589 validation accuracy=0.939667 ETA=0:11:34
# epoch 9/40   training error=0.162758  validation error=0.179830 validation accuracy=0.946333 ETA=0:11:19
# epoch 10/40   training error=0.153443  validation error=0.176376 validation accuracy=0.948000 ETA=0:11:05
# epoch 11/40   training error=0.145063  validation error=0.168923 validation accuracy=0.949167 ETA=0:10:48
# epoch 12/40   training error=0.137559  validation error=0.165025 validation accuracy=0.952750 ETA=0:10:26
# epoch 13/40   training error=0.130915  validation error=0.162125 validation accuracy=0.952417 ETA=0:10:09
# epoch 14/40   training error=0.125240  validation error=0.158027 validation accuracy=0.952417 ETA=0:09:52
# epoch 15/40   training error=0.119516  validation error=0.152648 validation accuracy=0.954333 ETA=0:09:29
# epoch 16/40   training error=0.114627  validation error=0.150872 validation accuracy=0.956500 ETA=0:09:08
# epoch 17/40   training error=0.110118  validation error=0.146771 validation accuracy=0.957750 ETA=0:08:54
# epoch 18/40   training error=0.105890  validation error=0.142853 validation accuracy=0.958583 ETA=0:08:33
# epoch 19/40   training error=0.102079  validation error=0.141617 validation accuracy=0.959167 ETA=0:08:08
# epoch 20/40   training error=0.098481  validation error=0.138857 validation accuracy=0.960167 ETA=0:07:42
# epoch 21/40   training error=0.095108  validation error=0.139727 validation accuracy=0.959250 ETA=0:07:21
# epoch 22/40   training error=0.091906  validation error=0.135842 validation accuracy=0.961000 ETA=0:07:02
# epoch 23/40   training error=0.088850  validation error=0.133421 validation accuracy=0.962500 ETA=0:06:50
# epoch 24/40   training error=0.086159  validation error=0.132896 validation accuracy=0.962250 ETA=0:06:30
# epoch 25/40   training error=0.083226  validation error=0.131454 validation accuracy=0.963667 ETA=0:06:07
# epoch 26/40   training error=0.080588  validation error=0.129636 validation accuracy=0.963500 ETA=0:05:47
# epoch 27/40   training error=0.078213  validation error=0.128432 validation accuracy=0.964167 ETA=0:05:27
# epoch 28/40   training error=0.075807  validation error=0.128313 validation accuracy=0.964583 ETA=0:05:05
# epoch 29/40   training error=0.073688  validation error=0.125592 validation accuracy=0.965417 ETA=0:04:40
# epoch 30/40   training error=0.071757  validation error=0.125663 validation accuracy=0.965000 ETA=0:04:16
# epoch 31/40   training error=0.069782  validation error=0.125056 validation accuracy=0.964917 ETA=0:03:52
# epoch 32/40   training error=0.068025  validation error=0.123508 validation accuracy=0.965917 ETA=0:03:26
# epoch 33/40   training error=0.065657  validation error=0.122941 validation accuracy=0.965583 ETA=0:03:01
# epoch 34/40   training error=0.064282  validation error=0.121293 validation accuracy=0.966500 ETA=0:02:37
# epoch 35/40   training error=0.062532  validation error=0.120338 validation accuracy=0.965583 ETA=0:02:10
# epoch 36/40   training error=0.060682  validation error=0.124150 validation accuracy=0.965917 ETA=0:01:45
# epoch 37/40   training error=0.059508  validation error=0.119800 validation accuracy=0.966833 ETA=0:01:19
# epoch 38/40   training error=0.057587  validation error=0.119398 validation accuracy=0.967333 ETA=0:00:53
# epoch 39/40   training error=0.056318  validation error=0.119337 validation accuracy=0.967500 ETA=0:00:26
# epoch 40/40   training error=0.054975  validation error=0.117433 validation accuracy=0.967333 ETA=0:00:00
# Average epoch computational time:  26.572604924440384
# Model accuracy  0.9662
# Fitting model 2/5 batchsize, 40 epochs - Fold 2 Layers: [100, 100]
# epoch 1/40   training error=0.742162  validation error=0.432597 validation accuracy=0.868667 ETA=0:17:33
# epoch 2/40   training error=0.344897  validation error=0.335552 validation accuracy=0.898500 ETA=0:16:58
# epoch 3/40   training error=0.278373  validation error=0.297953 validation accuracy=0.910167 ETA=0:16:58
# epoch 4/40   training error=0.241093  validation error=0.266142 validation accuracy=0.919083 ETA=0:16:37
# epoch 5/40   training error=0.216004  validation error=0.247363 validation accuracy=0.925667 ETA=0:17:04
# epoch 6/40   training error=0.197137  validation error=0.233612 validation accuracy=0.930417 ETA=0:17:19
# epoch 7/40   training error=0.182612  validation error=0.219243 validation accuracy=0.934750 ETA=0:16:50
# epoch 8/40   training error=0.170225  validation error=0.212316 validation accuracy=0.937500 ETA=0:15:55
# epoch 9/40   training error=0.160248  validation error=0.200783 validation accuracy=0.939667 ETA=0:15:06
# epoch 10/40   training error=0.151502  validation error=0.196253 validation accuracy=0.940500 ETA=0:14:31
# epoch 11/40   training error=0.143756  validation error=0.188111 validation accuracy=0.944167 ETA=0:14:27
# epoch 12/40   training error=0.136607  validation error=0.184254 validation accuracy=0.945167 ETA=0:13:52
# epoch 13/40   training error=0.130305  validation error=0.177574 validation accuracy=0.947083 ETA=0:13:14
# epoch 14/40   training error=0.124823  validation error=0.176297 validation accuracy=0.946667 ETA=0:12:41
# epoch 15/40   training error=0.119653  validation error=0.171902 validation accuracy=0.948250 ETA=0:12:09
# epoch 16/40   training error=0.115049  validation error=0.168961 validation accuracy=0.949500 ETA=0:11:40
# epoch 17/40   training error=0.110500  validation error=0.162689 validation accuracy=0.951333 ETA=0:11:07
# epoch 18/40   training error=0.106724  validation error=0.159996 validation accuracy=0.950417 ETA=0:10:36
# epoch 19/40   training error=0.102811  validation error=0.157773 validation accuracy=0.951417 ETA=0:10:01
# epoch 20/40   training error=0.098814  validation error=0.155829 validation accuracy=0.952417 ETA=0:09:27
# epoch 21/40   training error=0.096001  validation error=0.152575 validation accuracy=0.953500 ETA=0:09:00
# epoch 22/40   training error=0.093030  validation error=0.151339 validation accuracy=0.953250 ETA=0:08:35
# epoch 23/40   training error=0.089749  validation error=0.148861 validation accuracy=0.954167 ETA=0:08:03
# epoch 24/40   training error=0.087045  validation error=0.147322 validation accuracy=0.954833 ETA=0:07:30
# epoch 25/40   training error=0.084501  validation error=0.145541 validation accuracy=0.954583 ETA=0:06:58
# epoch 26/40   training error=0.082029  validation error=0.144262 validation accuracy=0.955500 ETA=0:06:29
# epoch 27/40   training error=0.079626  validation error=0.143314 validation accuracy=0.956083 ETA=0:05:58
# epoch 28/40   training error=0.077495  validation error=0.141706 validation accuracy=0.956167 ETA=0:05:30
# epoch 29/40   training error=0.075298  validation error=0.141200 validation accuracy=0.955833 ETA=0:05:01
# epoch 30/40   training error=0.073219  validation error=0.139689 validation accuracy=0.958000 ETA=0:04:32
# epoch 31/40   training error=0.071175  validation error=0.137774 validation accuracy=0.956917 ETA=0:04:05
# epoch 32/40   training error=0.069296  validation error=0.138956 validation accuracy=0.956750 ETA=0:03:38
# epoch 33/40   training error=0.067437  validation error=0.134535 validation accuracy=0.957833 ETA=0:03:10
# epoch 34/40   training error=0.065686  validation error=0.136348 validation accuracy=0.958167 ETA=0:02:43
# epoch 35/40   training error=0.064043  validation error=0.133797 validation accuracy=0.958750 ETA=0:02:16
# epoch 36/40   training error=0.062150  validation error=0.135823 validation accuracy=0.958417 ETA=0:01:50
# epoch 37/40   training error=0.060640  validation error=0.136426 validation accuracy=0.958250 ETA=0:01:23
# epoch 38/40   training error=0.059003  validation error=0.132303 validation accuracy=0.959833 ETA=0:00:55
# epoch 39/40   training error=0.057699  validation error=0.133263 validation accuracy=0.960417 ETA=0:00:28
# epoch 40/40   training error=0.056067  validation error=0.131221 validation accuracy=0.959500 ETA=0:00:00
# Average epoch computational time:  27.650999867916106
# Model accuracy  0.9643
# Fitting model 3/5 batchsize, 40 epochs - Fold 3 Layers: [100, 100]
# epoch 1/40   training error=0.728949  validation error=0.417906 validation accuracy=0.872417 ETA=0:21:50
# epoch 2/40   training error=0.347770  validation error=0.330209 validation accuracy=0.901083 ETA=0:20:23
# epoch 3/40   training error=0.282556  validation error=0.288110 validation accuracy=0.914583 ETA=0:20:00
# epoch 4/40   training error=0.245059  validation error=0.259539 validation accuracy=0.923417 ETA=0:19:27
# epoch 5/40   training error=0.219509  validation error=0.241475 validation accuracy=0.929667 ETA=0:18:57
# epoch 6/40   training error=0.200536  validation error=0.228988 validation accuracy=0.932083 ETA=0:18:11
# epoch 7/40   training error=0.185424  validation error=0.215646 validation accuracy=0.936083 ETA=0:17:45
# epoch 8/40   training error=0.172965  validation error=0.208436 validation accuracy=0.937833 ETA=0:17:16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6b48f45ea41d> in <module>
#      39
#      40 #execute queue
# ---> 41 results = queue.execute(folder="../Results/Extensions")
#
# ~\git\seminar\src\neuralnet\network_queue.py in execute(self, save, folder)
#      55                             val["params"]["batch_size"],
#      56                             val["params"]["momentum"],
# ---> 57                             val["params"]["weight_decay"])
#      58             self.queue[i]["accuracies"]= val["network"].accuracy(self.test_features, self.original_test_labels)
#      59             print("Model accuracy ",self.queue[i]["accuracies"])
#
# ~\git\seminar\src\neuralnet\network.py in fit(self, x_train, y_train, x_val, y_val, epochs, learning_rate, batch_size, momentum, weight_decay)
#      96
#      97             # train one epoch
# ---> 98             err = self.train_epoch(i, x_shuffle, y_shuffle, samples, learning_rate, batch_size, momentum, weight_decay)
#      99
#     100             # validate and save to epoch error lists
#
# ~\git\seminar\src\neuralnet\network.py in train_epoch(self, i, x_shuffle, y_shuffle, samples, learning_rate, batch_size, momentum, weight_decay)
#     146                 # backprop through all subsequent layers, while also updating parameters
#     147                 for layer in reversed(self.layers[:-1]):
# --> 148                     output_error = layer.backward_propagation(output_error, learning_rate, batch_size)
#     149
#     150             self.update_parameters(learning_rate, momentum=momentum, weight_decay=weight_decay)
#
# ~\git\seminar\src\neuralnet\Layer.py in backward_propagation(self, output_error, learning_rate, batch_size)
#      43     # computes dE/dW, dE/dB for a given output_error=dE/dY. Returns input_error=dE/dX.
#      44     def backward_propagation(self, output_error, learning_rate, batch_size=None):
# ---> 45         input_error = np.dot(self.weights, output_error.T).T
#      46         self.output_gradient += output_error/batch_size
#      47         dot = np.dot(self.input.T, output_error)
#
# KeyboardInterrupt:
